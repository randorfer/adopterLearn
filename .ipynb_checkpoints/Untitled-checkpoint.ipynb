# %%
% pylab inline
import pandas as pd
import numpy as np

train = pd.read_csv("data/train.csv")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
train.head(1)
# Out:
#    row_number  user_id  adopter  age  is_male  friend_count  avg_friend_age  \
# 0           1       10        0   24        0            20       26.333333
#
#    avg_friend_male  friend_country_cnt  subscriber_friend_cnt  \
# 0         0.777778                   6                      0
#
#           ...          delta_friend_country_cnt  delta_subscriber_friend_cnt  \
# 0         ...                                 0                            0
#
#    delta_songs_listened  delta_loved_tracks  delta_posts  delta_playlists  \
# 0                    54                   0            0                0
#
#    delta_shouts  tenure  good_country  delta_good_country
# 0             0      79             0                   0
#
# [1 rows x 28 columns]

# %%
train.describe()
# Out:
#          row_number       user_id       adopter           age       is_male  \
# count  86682.000000  8.668200e+04  86682.000000  86682.000000  86682.000000
# mean   43341.500000  8.547774e+05      0.017766     23.993067      0.622217
# std    25023.082354  4.938304e+05      0.132101      6.388225      0.484836
# min        1.000000  1.000000e+01      0.000000      8.000000      0.000000
# 25%    21671.250000  4.279675e+05      0.000000     20.000000      0.000000
# 50%    43341.500000  8.520060e+05      0.000000     23.000000      1.000000
# 75%    65011.750000  1.282592e+06      0.000000     26.000000      1.000000
# max    86682.000000  1.708942e+06      1.000000     79.000000      1.000000
#
#        friend_count  avg_friend_age  avg_friend_male  friend_country_cnt  \
# count  86682.000000    86682.000000     86682.000000        86682.000000
# mean      18.988521       24.068308         0.617246            4.040147
# std       57.934430        5.127068         0.318587            5.843532
# min        1.000000        9.000000         0.000000            0.000000
# 25%        3.000000       20.750000         0.428571            1.000000
# 50%        7.000000       23.000000         0.666667            2.000000
# 75%       18.000000       26.157895         0.900000            4.000000
# max     6437.000000       77.000000         1.000000          122.000000
#
#        subscriber_friend_cnt         ...          delta_friend_country_cnt  \
# count           86682.000000         ...                      86682.000000
# mean                0.434935         ...                          0.105847
# std                 1.853233         ...                          0.843507
# min                 0.000000         ...                        -29.000000
# 25%                 0.000000         ...                          0.000000
# 50%                 0.000000         ...                          0.000000
# 75%                 0.000000         ...                          0.000000
# max               225.000000         ...                         41.000000
#
#        delta_subscriber_friend_cnt  delta_songs_listened  delta_loved_tracks  \
# count                 86682.000000          86682.000000        86682.000000
# mean                     -0.021054            942.677188            4.716723
# std                       0.534960           2856.036359          155.648950
# min                     -18.000000        -135022.000000         -951.000000
# 25%                       0.000000              0.000000            0.000000
# 50%                       0.000000              0.000000            0.000000
# 75%                       0.000000            913.000000            0.000000
# max                      19.000000         217876.000000        44900.000000
#
#         delta_posts  delta_playlists  delta_shouts        tenure  \
# count  86682.000000     86682.000000  86682.000000  86682.000000
# mean       0.279158         0.002757      0.954500     44.350061
# std       43.782235         0.177153     19.209259     19.707058
# min     -264.000000        -5.000000  -2752.000000      0.000000
# 25%        0.000000         0.000000      0.000000     29.000000
# 50%        0.000000         0.000000      0.000000     45.000000
# 75%        0.000000         0.000000      0.000000     59.000000
# max    12702.000000        20.000000   2036.000000    112.000000
#
#        good_country  delta_good_country
# count  86682.000000        86682.000000
# mean       0.352045            0.000242
# std        0.477611            0.034803
# min        0.000000           -1.000000
# 25%        0.000000            0.000000
# 50%        0.000000            0.000000
# 75%        1.000000            0.000000
# max        1.000000            1.000000
#
# [8 rows x 28 columns]

# %%
train.age.hist(bins=30)
plt.title("Distribution of users' ages")
plt.ylabel('count of users')
plt.xlablel('age')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-c1438391bdbc> in <module>()
#       2 plt.title("Distribution of users' ages")
#       3 plt.ylabel('count of users')
# ----> 4 plt.xlablel('age')
#
# AttributeError: 'module' object has no attribute 'xlablel'
